# %% [markdown]
# <a href="https://colab.research.google.com/github/kaushal4445/GEN_AI-TRAINING-CGC-UNIVERSITY/blob/main/LEARNING_PYTHON/GenAI_Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tuple - immutable means can't be changed or modified
#
#
#
# *   are used to store hetrogenus
# *   aere used to store duploicate
# *   are used to declare paranthesis
# *   insertio  order are preserved

# %%
t1 = ()
t2 = (1, 2, 3, 4)
t3 =11, 22, 33
print(t3)
# Out:
# (11, 22, 33)

# %%
t4 = (11, 22, [101, 102])
t5 = ((1, 2, 3), ("sun", "mon", "tue",))
print(t4)
print(t5)
# Out:
# (11, 22, [101, 102])
# ((1, 2, 3), ('sun', 'mon', 'tue'))

# %%
t = (1, 2, 3, 4, 5, 6, 7, 8)
#count, index, remove, remove, pop, sort, reverse, append, extend
#sum, max, min, len
l = [1, 2, 3]
l2 =[11, 22, 33]
l.append(l2)

# %%
t = (1, 2, 3, 4, 5, 6, 7, 8)
print(t.count(2))    # 1
print(t.index(5))    # 4
print(sum(t))       # 36
print(max(t))       # 8
print(min(t))       # 1
print(len(t))       # 8
# Out:
# 1
# 4
# 36
# 8
# 1
# 8

# %%
l = [1, 2, 3]
l2 = [11, 22, 33]
l.append(4)
print(l)
# Out:
# [1, 2, 3, 4]

# %%
l.append(l2)
print(l)
# Out:
# [1, 2, 3, 4, [11, 22, 33]]

# %% [markdown]
# # **how to delete elements in a tuple?**

# %%
n =(1, 2, 3, 4)
tt = list(n)
print(tt)
tt.remove(4)
print(tt)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3]

# %% [markdown]
# # **can yoy  explain how list is mutable and and tuple are immutable**

# %%
t = [1, 2, 3 ,4]
t[2] = 111
print(t)
t1 = (1, 2,3, 4, 5)
t1[2] = 222
print(t1)
# Out:
# [1, 2, 111, 4]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_495/765307176.py in <cell line: 0>()
#       3 print(t)
#       4 t1 = (1, 2,3, 4, 5)
# ----> 5 t1[2] = 222
#       6 print(t1)
#
# TypeError: 'tuple' object does not support item assignment

# %%
# send more questions related to tuple and list

# %% [markdown]
# Set - are mutable are used to store unique elements
#
#
# 1.   set are unorderd
# 2.   are used to declared{}
# 3.  slicing are not accessible
# 4.  inddexing not accessible

# %%
s1 = {"sun", "mon", "tue", "wed", "thur"}
print(s1)
s1.add("jan")
print(s1)
s1.add("mar")
print(s1)
# Out:
# {'wed', 'thur', 'mon', 'sun', 'tue'}
# {'wed', 'jan', 'thur', 'mon', 'sun', 'tue'}
# {'wed', 'jan', 'thur', 'mar', 'mon', 'sun', 'tue'}

# %%
#how you modified
#how to delete
s1.update(["ram"])
print(s1)

s1.remove("ram")
print(s1)
# Out:
# {'wed', 'jan', 'thur', 'mar', 'mon', 'sun', 'tue', 'ram'}
# {'wed', 'jan', 'thur', 'mar', 'mon', 'sun', 'tue'}

# %% [markdown]
# Dictionary - are used to store hey-values pair where key are nique and values may be duplicate
#
#
#
# *   dictionary are mutable
# *   insertion order preserver
# *   slicing are mnot possible

# %%
d1 = dict()
print(type(d1))
# Out:
# <class 'dict'>

# %%
d = {
    "id" : 1,
    "name" : "suresh",
    "course" : "java",
    "age" : 23,
    "city" : "noida"
    }

print(d)
# Out:
# {'id': 1, 'name': 'suresh', 'course': 'java', 'age': 23, 'city': 'noida'}

# %%
k = [1, 2, 3 , 4]
v = ["pitter", "david", "warner", "parker"]
d = dict(zip(k, v))
print(d)
print(d.keys())
print(d.values())
print(d.items())
# Out:
# {1: 'pitter', 2: 'david', 3: 'warner', 4: 'parker'}
# dict_keys([1, 2, 3, 4])
# dict_values(['pitter', 'david', 'warner', 'parker'])
# dict_items([(1, 'pitter'), (2, 'david'), (3, 'warner'), (4, 'parker')])

# %%
k = ["id", "name", "post", "salary"]
v = [101, "sonu", "developer", 23000]
d = dict(zip(k, v))
print(d)
print(d["name"])
print(d.get("salary"))
# Out:
# {'id': 101, 'name': 'sonu', 'post': 'developer', 'salary': 23000}
# sonu
# 23000

# %%
d = {
    "id" : 11,
    "name" : "hari",
}
print(d)
#add
d["course"] = " java"
print(d)
d.update({"marks" : 20})
print(d)
# remove
d.pop("marks")
print(d)
# Out:
# {'id': 11, 'name': 'hari'}
# {'id': 11, 'name': 'hari', 'course': ' java'}
# {'id': 11, 'name': 'hari', 'course': ' java', 'marks': 20}
# {'id': 11, 'name': 'hari', 'course': ' java'}

# %% [markdown]
# # **Implementation of dictionary mini project**

# %%
employee = dict()
while True:
  print("1 . Add")
  print("2. View")
  print("3 . Search")
  print("4. Update")
  print("5. Delete")
  print("6, Exit")
  choice = int(input("Enter your choice"))
  if choice == 1:
    id = int(input("Enter employee id"))
    name = input("Enter employee name")
    post = input("Enter employee post")
    salary = int(input("Enter employee salary"))
    employee[id] ={
        "name" : name,
        "post" : post,
        "salary" : salary
    }
    print("Employee Added Successffully")
  elif choice == 2:
    if employee:
      for id , emp in employee.items():
        print("Emp id", id)
        print("Emp name", emp["name"])
        print("Emp post", emp["post"])
        print("Emp salary", emp["salary"])
    else:
      print("No employee found")
  elif choice == 3:
    id = int(input("Enter employee id"))
    if id in employee:
      print("Emp NAME :", employee[id]["name"])
      print("Emp POST :", employee[id]["post"])
      print("Emp SALARY :", employee[id]["salary"])
    else:
      print("EmployeeID not found")
  elif choice == 4:
    id = int(input("Enter employee id"))
    if id in employee:
      name = input("Enter employee name")
      post = input("Enter employee post")
      salary = int(input("Enter employee salary"))
      employee[id] ={
        "name" : name,
        "post" : post,
        "salary" : salary
      }
      print("Employee Updated Successffully")
    else:
      print("Employee not found")
  elif choice == 5:
    id = int(input("Enter employee id"))
    if id in employee:
      employee.pop(id)
      print("Employee Deleted Successffully")
    else:
      print("Employee not found")
  elif choice == 6:
    break
  else:
      print("Invalid choice")
# Out:
# 1 . Add
# 2. View
# 3 . Search
# 4. Update
# 5. Delete
# 6, Exit
# Enter your choice7
# Invalid choice
# 1 . Add
# 2. View
# 3 . Search
# 4. Update
# 5. Delete
# 6, Exit
# Enter your choice7
# Invalid choice
# 1 . Add
# 2. View
# 3 . Search
# 4. Update
# 5. Delete
# 6, Exit
# Enter your choicejhhi
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_495/572618624.py in <cell line: 0>()
#       7   print("5. Delete")
#       8   print("6, Exit")
# ----> 9   choice = int(input("Enter your choice"))
#      10   if choice == 1:
#      11     id = int(input("Enter employee id"))
#
# ValueError: invalid literal for int() with base 10: 'jhhi'

# %% [markdown]
# Error and exception
#
# real life or development
#
# compile and runtime

# %% [markdown]
# def keyword is uded to declare function

# %%
def show():
  print("hello")

show()

# %%
def sum(a, b):
  print(a+ b)
sum(10, 20)

# %%
a = int(input("Enter a number 1"))
b = int(input("Enter a number 2"))
def add():
  print(a + b)
def sub():
  print(a - b)
def multi():
  print(a * b)
def div():
  print(a/b)

# %% [markdown]
# # **types of fuctions**
#
# take something resturn something
#
# take nothing retur nothing
#
# take something return nothing
#
# take nothing return something

# %%
#tells hw about abstract class
